# %%
import pandas as pd
from pathlib import Path

HOME_PATH = Path("..")

# %%
df = pd.read_csv(HOME_PATH / "data/dataset/AzharAli05_Resume_Screening_Dataset.csv")
df.head()
# Out:
#                     role                                             resume  \
# 0  E-commerce Specialist  Jason Jones\nE-commerce Specialist\n\nContact ...
# 1  E-commerce Specialist  Patricia Gray\nContact Information:\n\n* Email...
# 2  E-commerce Specialist  Amanda Gross\nContact Information:\n\n* Email:...
# 3   Mobile App Developer  Jose Hall\nContact Information:\n\n* Email: [j...
# 4         Cloud Engineer  Jessica Hall\nCloud Engineer\n\nContact Inform...
#
#    decision                                          reasoning  \
# 0     False    Lacked leadership skills for a senior position.
# 1      True  Impressive leadership and communication abilit...
# 2     False    Lacked leadership skills for a senior position.
# 3     False             No experience in back-end development.
# 4     False  Needs improvement in machine learning algorithms.
#
#                                          description
# 0  Be part of a passionate team at the forefront ...
# 1  Be part of a passionate team at the forefront ...
# 2  We are looking for an experienced E-commerce S...
# 3  We need a Mobile App Developer to enhance our ...
# 4  We're seeking a talented Cloud Engineer to wor...

# %%
df['description'].sample(5, random_state=0)
# Out:
# 311     As a System Administrator, you will play a piv...
# 154     As a Product Manager, you will play a pivotal ...
# 2027    Looking for an experienced Product Manager to ...
# 1687    Be part of a passionate team at the forefront ...
# 1519    We are looking for an experienced IT Support S...
# Name: description, dtype: object

# %%
# grab ten random jobs
jobs = df['description'].drop_duplicates().sample(n=5, random_state=0)
jobs
# Out:
# 56     We're seeking a talented Data Architect to wor...
# 421    We are looking for an experienced DevOps Engin...
# 322    Looking for an experienced Cloud Architect to ...
# 340    Take the lead in driving innovation as a Syste...
# 31     As a Data Engineer, you will play a pivotal ro...
# Name: description, dtype: object

# %%
df = df[df['description'].isin(jobs)]
df = df.groupby(['description', 'decision'], group_keys=False).apply(lambda df: df.sample(n=1, random_state=0)).reset_index(drop=True)
df
# Out:
# C:\Users\dyaom\AppData\Local\Temp\ipykernel_9208\2742138597.py:2: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['description', 'decision'], group_keys=False).apply(lambda df: df.sample(n=1, random_state=0)).reset_index(drop=True)
#                    role                                             resume  \
# 0         Data Engineer  Alan Ross\nContact Information:\n\n* Email: [a...
# 1         Data Engineer  Tanner Harris\nData Engineer\n\nContact Inform...
# 2       Cloud Architect  Jamie Rowe\nCloud Architect\n\nContact Informa...
# 3       Cloud Architect  Jason Ward\nCloud Architect\n\nContact Informa...
# 4  System Administrator  Benjamin Rogers\nSystem Administrator\n\nConta...
# 5  System Administrator  Michael Yu\nSystem Administrator\n\nContact In...
# 6       DevOps Engineer  Francisco Werner\nContact Information:\n\n* Ph...
# 7       DevOps Engineer  Margaret Russell\nDevOps Engineer\n\nContact I...
# 8        Data Architect  Debra Brown\nData Architect\n\nContact Informa...
# 9        Data Architect  Antonio Turner\nContact Information:\n\n* Emai...
#
#    decision                                          reasoning  \
# 0     False  Insufficient system design expertise for senio...
# 1      True              Strong technical skills in AI and ML.
# 2     False    Lacks hands-on experience with cloud platforms.
# 3      True       Excellent full-stack development experience.
# 4     False  Insufficient system design expertise for senio...
# 5      True       Excellent full-stack development experience.
# 6     False  Insufficient system design expertise for senio...
# 7      True       Solid experience in machine learning and AI.
# 8     False    Lacked leadership skills for a senior position.
# 9      True       Solid experience in machine learning and AI.
#
#                                          description
# 0  As a Data Engineer, you will play a pivotal ro...
# 1  As a Data Engineer, you will play a pivotal ro...
# 2  Looking for an experienced Cloud Architect to ...
# 3  Looking for an experienced Cloud Architect to ...
# 4  Take the lead in driving innovation as a Syste...
# 5  Take the lead in driving innovation as a Syste...
# 6  We are looking for an experienced DevOps Engin...
# 7  We are looking for an experienced DevOps Engin...
# 8  We're seeking a talented Data Architect to wor...
# 9  We're seeking a talented Data Architect to wor...

# %%
# let's convert this to a "standard form"
new_dict = [
    {
        'description': d,
        'resume_accept': df[
            (df['description']==d) & (df['decision']==True)
        ]['resume'].item(),
        'resume_reject': df[
            (df['description']==d) & (df['decision']==False)
        ]['resume'].item(),
    } for d in df['description'].unique()
]
df_2 = pd.DataFrame(new_dict)
df_2
# Out:
#                                          description  \
# 0  As a Data Engineer, you will play a pivotal ro...
# 1  Looking for an experienced Cloud Architect to ...
# 2  Take the lead in driving innovation as a Syste...
# 3  We are looking for an experienced DevOps Engin...
# 4  We're seeking a talented Data Architect to wor...
#
#                                        resume_accept  \
# 0  Tanner Harris\nData Engineer\n\nContact Inform...
# 1  Jason Ward\nCloud Architect\n\nContact Informa...
# 2  Michael Yu\nSystem Administrator\n\nContact In...
# 3  Margaret Russell\nDevOps Engineer\n\nContact I...
# 4  Antonio Turner\nContact Information:\n\n* Emai...
#
#                                        resume_reject
# 0  Alan Ross\nContact Information:\n\n* Email: [a...
# 1  Jamie Rowe\nCloud Architect\n\nContact Informa...
# 2  Benjamin Rogers\nSystem Administrator\n\nConta...
# 3  Francisco Werner\nContact Information:\n\n* Ph...
# 4  Debra Brown\nData Architect\n\nContact Informa...

# %%
df_2.to_csv(HOME_PATH / "data/dataset/AzharAli05_Resume_subset.csv", index=False)
