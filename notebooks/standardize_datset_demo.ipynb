# %%
import pandas as pd
from pathlib import Path

HOME_PATH = Path("..")

# %%
df = pd.read_csv(HOME_PATH / "data/dataset/AzharAli05_Resume_Screening_Dataset.csv")
df.head()
# Out:
#                     role                                             resume  \
# 0  E-commerce Specialist  Jason Jones\nE-commerce Specialist\n\nContact ...
# 1  E-commerce Specialist  Patricia Gray\nContact Information:\n\n* Email...
# 2  E-commerce Specialist  Amanda Gross\nContact Information:\n\n* Email:...
# 3   Mobile App Developer  Jose Hall\nContact Information:\n\n* Email: [j...
# 4         Cloud Engineer  Jessica Hall\nCloud Engineer\n\nContact Inform...
#
#    decision                                          reasoning  \
# 0     False    Lacked leadership skills for a senior position.
# 1      True  Impressive leadership and communication abilit...
# 2     False    Lacked leadership skills for a senior position.
# 3     False             No experience in back-end development.
# 4     False  Needs improvement in machine learning algorithms.
#
#                                          description
# 0  Be part of a passionate team at the forefront ...
# 1  Be part of a passionate team at the forefront ...
# 2  We are looking for an experienced E-commerce S...
# 3  We need a Mobile App Developer to enhance our ...
# 4  We're seeking a talented Cloud Engineer to wor...

# %%
df['description'].sample(20, random_state=0)
# Out:
# 311     As a System Administrator, you will play a piv...
# 154     As a Product Manager, you will play a pivotal ...
# 2027    Looking for an experienced Product Manager to ...
# 1687    Be part of a passionate team at the forefront ...
# 1519    We are looking for an experienced IT Support S...
# 2044    We are looking for an experienced Data Analyst...
# 4100    Be part of a passionate team at the forefront ...
# 4684    Help us build the next-generation products as ...
# 1881    Help us build the next-generation products as ...
# 1108    We are looking for an experienced Mobile App D...
# 125     Be part of a passionate team at the forefront ...
# 1939    Take the lead in driving innovation as a Softw...
# 1900    Be part of a passionate team at the forefront ...
# 49      As a Content Writer, you will play a pivotal r...
# 3985    Help us build the next-generation products as ...
# 534     We're seeking a talented QA Engineer to work o...
# 4452    We're seeking a talented Blockchain Developer ...
# 3278    Be part of a passionate team at the forefront ...
# 3863    Be part of a passionate team at the forefront ...
# 347     As a Data Architect, you will play a pivotal r...
# Name: description, dtype: object

# %%
# grab ten random jobs
jobs = df['description'].drop_duplicates().sample(n=20, random_state=0)
jobs
# Out:
# 56      We're seeking a talented Data Architect to wor...
# 421     We are looking for an experienced DevOps Engin...
# 322     Looking for an experienced Cloud Architect to ...
# 340     Take the lead in driving innovation as a Syste...
# 31      As a Data Engineer, you will play a pivotal ro...
# 509     Take the lead in driving innovation as a Block...
# 349     Be part of a passionate team at the forefront ...
# 415     Be part of a passionate team at the forefront ...
# 1509    As a Digital Marketing Specialist, you'll lead...
# 1543    As a AI Researcher, you will play a pivotal ro...
# 1024    If you're passionate about cloud technologies,...
# 1799    Looking for an experienced Cloud Engineer to j...
# 2409    As a Software Engineer, you will play a pivota...
# 682     We need a UX Designer to enhance our team's te...
# 4084    Join our fast-growing team and help us scale o...
# 1343    As a UX Designer, you will play a pivotal role...
# 285     As a Blockchain Developer, you'll lead the des...
# 161     We're hiring a E-commerce Specialist to develo...
# 718     Join our fast-growing team and help us scale o...
# 1517    We're hiring a Software Engineer to develop an...
# Name: description, dtype: object

# %%
df = df[df['description'].isin(jobs)]
df = df.groupby(['description', 'decision'], group_keys=False).apply(lambda df: df.sample(n=1, random_state=0)).reset_index(drop=True)
df
# Out:
# /var/folders/z_/49jlm0q172zchrpp1qrxswc80000gn/T/ipykernel_77423/2742138597.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['description', 'decision'], group_keys=False).apply(lambda df: df.sample(n=1, random_state=0)).reset_index(drop=True)
#                             role  \
# 0                  AI Researcher
# 1                  AI Researcher
# 2           Blockchain Developer
# 3           Blockchain Developer
# 4                  Data Engineer
# 5                  Data Engineer
# 6   Digital Marketing Specialist
# 7   Digital Marketing Specialist
# 8              Software Engineer
# 9              Software Engineer
# 10                   UX Designer
# 11                   UX Designer
# 12    Human Resources Specialist
# 13    Human Resources Specialist
# 14                Content Writer
# 15                Content Writer
# 16                   QA Engineer
# 17                   QA Engineer
# 18               Cloud Architect
# 19               Cloud Architect
# 20         E-commerce Specialist
# 21         E-commerce Specialist
# 22               Cloud Architect
# 23               Cloud Architect
# 24                Cloud Engineer
# 25                Cloud Engineer
# 26          Blockchain Developer
# 27          Blockchain Developer
# 28          System Administrator
# 29          System Administrator
# 30               DevOps Engineer
# 31               DevOps Engineer
# 32                   UX Designer
# 33                   UX Designer
# 34         E-commerce Specialist
# 35         E-commerce Specialist
# 36             Software Engineer
# 37             Software Engineer
# 38                Data Architect
# 39                Data Architect
#
#                                                resume  decision  \
# 0   Darlene Williams\nContact Information:\n\n* Em...     False
# 1   Melanie Livingston\nAI Researcher\n\nContact I...      True
# 2   April Rodriguez\nBlockchain Developer\n\nConta...     False
# 3   Bethany Rodriguez\nContact Information:\n\n* P...      True
# 4   Alan Ross\nContact Information:\n\n* Email: [a...     False
# 5   Tanner Harris\nData Engineer\n\nContact Inform...      True
# 6   Kristin Hamilton\nDigital Marketing Specialist...     False
# 7   Elizabeth Mccall\nContact Information:\n\n* Em...      True
# 8   Emily Palmer\nSoftware Engineer\n\nContact Inf...     False
# 9   Renee Woods\nSoftware Engineer\n\nContact Info...      True
# 10  Kristi Bryant\nUX Designer\n\nContact Informat...     False
# 11  Andrew Goodwin\nContact Information:\n\n* Phon...      True
# 12  Tammy Payne\nContact Information:\n\n* Address...     False
# 13  Travis Hamilton\nContact Information:\n\n* Add...      True
# 14  James Ramos\nContact Information:\n\n* Email: ...     False
# 15  Desiree Gutierrez\nContact Information:\n\n* E...      True
# 16  Alisha Graham\nContact Information:\n\n* Email...     False
# 17  Daniel Lopez\nContact Information:\n\n* Email:...      True
# 18  Justin Peterson\nCloud Architect\n\nContact In...     False
# 19  Michael Powell\nCloud Architect\n\nContact Inf...      True
# 20  Jesse Martin\nContact Information:\n\n* Addres...     False
# 21  Stephen Lopez\nContact Information:\n\n* Addre...      True
# 22  Jamie Rowe\nCloud Architect\n\nContact Informa...     False
# 23  Jason Ward\nCloud Architect\n\nContact Informa...      True
# 24  Dominique Brewer\nCloud Engineer\n\nContact In...     False
# 25  Cynthia Norman\nCloud Engineer\n\nContact Info...      True
# 26  Amanda Madden\nBlockchain Developer\n\nContact...     False
# 27  Michael Andrade\nBlockchain Developer\n\nConta...      True
# 28  Benjamin Rogers\nSystem Administrator\n\nConta...     False
# 29  Michael Yu\nSystem Administrator\n\nContact In...      True
# 30  Francisco Werner\nContact Information:\n\n* Ph...     False
# 31  Margaret Russell\nDevOps Engineer\n\nContact I...      True
# 32  Andre Erickson\nUX Designer\n\nContact Informa...     False
# 33  Colleen Rodriguez\nUX Designer\n\nContact Info...      True
# 34  Lynn Hughes\nE-commerce Specialist\n\nContact ...     False
# 35  Shelley Brown\nE-commerce Specialist\n\nContac...      True
# 36  Michele Floyd\nSoftware Engineer\n\nContact In...     False
# 37  Rebecca Wilcox\nSoftware Engineer\n\nContact I...      True
# 38  Debra Brown\nData Architect\n\nContact Informa...     False
# 39  Antonio Turner\nContact Information:\n\n* Emai...      True
#
#                                             reasoning  \
# 0              No experience in back-end development.
# 1   Impressive leadership and communication abilit...
# 2     Lacked leadership skills for a senior position.
# 3        Excellent full-stack development experience.
# 4   Insufficient system design expertise for senio...
# 5               Strong technical skills in AI and ML.
# 6   Insufficient system design expertise for senio...
# 7        Excellent full-stack development experience.
# 8     Lacks hands-on experience with cloud platforms.
# 9        Solid experience in machine learning and AI.
# 10  Needs improvement in machine learning algorithms.
# 11  Impressive leadership and communication abilit...
# 12  Insufficient system design expertise for senio...
# 13              Strong technical skills in AI and ML.
# 14    Lacked leadership skills for a senior position.
# 15       Solid experience in machine learning and AI.
# 16    Lacks hands-on experience with cloud platforms.
# 17              Strong technical skills in AI and ML.
# 18  Needs improvement in machine learning algorithms.
# 19       Solid experience in machine learning and AI.
# 20  Insufficient system design expertise for senio...
# 21  Impressive leadership and communication abilit...
# 22    Lacks hands-on experience with cloud platforms.
# 23       Excellent full-stack development experience.
# 24    Lacks hands-on experience with cloud platforms.
# 25  Impressive leadership and communication abilit...
# 26  Insufficient system design expertise for senio...
# 27              Strong technical skills in AI and ML.
# 28  Insufficient system design expertise for senio...
# 29       Excellent full-stack development experience.
# 30  Insufficient system design expertise for senio...
# 31       Solid experience in machine learning and AI.
# 32             No experience in back-end development.
# 33     Perfectly aligned with data engineering needs.
# 34  Insufficient system design expertise for senio...
# 35              Strong technical skills in AI and ML.
# 36             No experience in back-end development.
# 37  Impressive leadership and communication abilit...
# 38    Lacked leadership skills for a senior position.
# 39       Solid experience in machine learning and AI.
#
#                                           description
# 0   As a AI Researcher, you will play a pivotal ro...
# 1   As a AI Researcher, you will play a pivotal ro...
# 2   As a Blockchain Developer, you'll lead the des...
# 3   As a Blockchain Developer, you'll lead the des...
# 4   As a Data Engineer, you will play a pivotal ro...
# 5   As a Data Engineer, you will play a pivotal ro...
# 6   As a Digital Marketing Specialist, you'll lead...
# 7   As a Digital Marketing Specialist, you'll lead...
# 8   As a Software Engineer, you will play a pivota...
# 9   As a Software Engineer, you will play a pivota...
# 10  As a UX Designer, you will play a pivotal role...
# 11  As a UX Designer, you will play a pivotal role...
# 12  Be part of a passionate team at the forefront ...
# 13  Be part of a passionate team at the forefront ...
# 14  Be part of a passionate team at the forefront ...
# 15  Be part of a passionate team at the forefront ...
# 16  If you're passionate about cloud technologies,...
# 17  If you're passionate about cloud technologies,...
# 18  Join our fast-growing team and help us scale o...
# 19  Join our fast-growing team and help us scale o...
# 20  Join our fast-growing team and help us scale o...
# 21  Join our fast-growing team and help us scale o...
# 22  Looking for an experienced Cloud Architect to ...
# 23  Looking for an experienced Cloud Architect to ...
# 24  Looking for an experienced Cloud Engineer to j...
# 25  Looking for an experienced Cloud Engineer to j...
# 26  Take the lead in driving innovation as a Block...
# 27  Take the lead in driving innovation as a Block...
# 28  Take the lead in driving innovation as a Syste...
# 29  Take the lead in driving innovation as a Syste...
# 30  We are looking for an experienced DevOps Engin...
# 31  We are looking for an experienced DevOps Engin...
# 32  We need a UX Designer to enhance our team's te...
# 33  We need a UX Designer to enhance our team's te...
# 34  We're hiring a E-commerce Specialist to develo...
# 35  We're hiring a E-commerce Specialist to develo...
# 36  We're hiring a Software Engineer to develop an...
# 37  We're hiring a Software Engineer to develop an...
# 38  We're seeking a talented Data Architect to wor...
# 39  We're seeking a talented Data Architect to wor...

# %%
# let's convert this to a "standard form"
new_dict = [
    {
        'description': d,
        'resume_accept': df[
            (df['description']==d) & (df['decision']==True)
        ]['resume'].item(),
        'resume_reject': df[
            (df['description']==d) & (df['decision']==False)
        ]['resume'].item(),
    } for d in df['description'].unique()
]
df_2 = pd.DataFrame(new_dict)
df_2
# Out:
#                                           description  \
# 0   As a AI Researcher, you will play a pivotal ro...
# 1   As a Blockchain Developer, you'll lead the des...
# 2   As a Data Engineer, you will play a pivotal ro...
# 3   As a Digital Marketing Specialist, you'll lead...
# 4   As a Software Engineer, you will play a pivota...
# 5   As a UX Designer, you will play a pivotal role...
# 6   Be part of a passionate team at the forefront ...
# 7   Be part of a passionate team at the forefront ...
# 8   If you're passionate about cloud technologies,...
# 9   Join our fast-growing team and help us scale o...
# 10  Join our fast-growing team and help us scale o...
# 11  Looking for an experienced Cloud Architect to ...
# 12  Looking for an experienced Cloud Engineer to j...
# 13  Take the lead in driving innovation as a Block...
# 14  Take the lead in driving innovation as a Syste...
# 15  We are looking for an experienced DevOps Engin...
# 16  We need a UX Designer to enhance our team's te...
# 17  We're hiring a E-commerce Specialist to develo...
# 18  We're hiring a Software Engineer to develop an...
# 19  We're seeking a talented Data Architect to wor...
#
#                                         resume_accept  \
# 0   Melanie Livingston\nAI Researcher\n\nContact I...
# 1   Bethany Rodriguez\nContact Information:\n\n* P...
# 2   Tanner Harris\nData Engineer\n\nContact Inform...
# 3   Elizabeth Mccall\nContact Information:\n\n* Em...
# 4   Renee Woods\nSoftware Engineer\n\nContact Info...
# 5   Andrew Goodwin\nContact Information:\n\n* Phon...
# 6   Travis Hamilton\nContact Information:\n\n* Add...
# 7   Desiree Gutierrez\nContact Information:\n\n* E...
# 8   Daniel Lopez\nContact Information:\n\n* Email:...
# 9   Michael Powell\nCloud Architect\n\nContact Inf...
# 10  Stephen Lopez\nContact Information:\n\n* Addre...
# 11  Jason Ward\nCloud Architect\n\nContact Informa...
# 12  Cynthia Norman\nCloud Engineer\n\nContact Info...
# 13  Michael Andrade\nBlockchain Developer\n\nConta...
# 14  Michael Yu\nSystem Administrator\n\nContact In...
# 15  Margaret Russell\nDevOps Engineer\n\nContact I...
# 16  Colleen Rodriguez\nUX Designer\n\nContact Info...
# 17  Shelley Brown\nE-commerce Specialist\n\nContac...
# 18  Rebecca Wilcox\nSoftware Engineer\n\nContact I...
# 19  Antonio Turner\nContact Information:\n\n* Emai...
#
#                                         resume_reject
# 0   Darlene Williams\nContact Information:\n\n* Em...
# 1   April Rodriguez\nBlockchain Developer\n\nConta...
# 2   Alan Ross\nContact Information:\n\n* Email: [a...
# 3   Kristin Hamilton\nDigital Marketing Specialist...
# 4   Emily Palmer\nSoftware Engineer\n\nContact Inf...
# 5   Kristi Bryant\nUX Designer\n\nContact Informat...
# 6   Tammy Payne\nContact Information:\n\n* Address...
# 7   James Ramos\nContact Information:\n\n* Email: ...
# 8   Alisha Graham\nContact Information:\n\n* Email...
# 9   Justin Peterson\nCloud Architect\n\nContact In...
# 10  Jesse Martin\nContact Information:\n\n* Addres...
# 11  Jamie Rowe\nCloud Architect\n\nContact Informa...
# 12  Dominique Brewer\nCloud Engineer\n\nContact In...
# 13  Amanda Madden\nBlockchain Developer\n\nContact...
# 14  Benjamin Rogers\nSystem Administrator\n\nConta...
# 15  Francisco Werner\nContact Information:\n\n* Ph...
# 16  Andre Erickson\nUX Designer\n\nContact Informa...
# 17  Lynn Hughes\nE-commerce Specialist\n\nContact ...
# 18  Michele Floyd\nSoftware Engineer\n\nContact In...
# 19  Debra Brown\nData Architect\n\nContact Informa...

# %%
df_2.to_csv(HOME_PATH / "data/dataset/AzharAli05_Resume_subset.csv", index=False)
